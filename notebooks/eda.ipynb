# %% [markdown]
# # import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # load dataset

# %%
df_phishing = pd.read_csv('phishing_urls.csv')
df_benign = pd.read_csv('benign_urls.csv')

# %%
df_phishing['label'] = 1
df_benign['label'] = 0

# %% [markdown]
# # perform EDA

# %%
df_benign.head()
# Out:
#    Unnamed: 0                        url        Type  label
# 0           0     https://www.google.com  legitimate      0
# 1           1    https://www.youtube.com  legitimate      0
# 2           2   https://www.facebook.com  legitimate      0
# 3           3      https://www.baidu.com  legitimate      0
# 4           4  https://www.wikipedia.org  legitimate      0

# %%
df_benign.shape
# Out:
# (345737, 4)

# %%
df_benign.columns
# Out:
# Index(['Unnamed: 0', 'url', 'Type', 'label'], dtype='object')

# %%
df_benign.isna().sum()
# Out:
# Unnamed: 0    0
# url           0
# Type          0
# label         0
# dtype: int64

# %%
df_benign.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345737 entries, 0 to 345736
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  345737 non-null  int64
#  1   url         345737 non-null  object
#  2   Type        345737 non-null  object
#  3   label       345737 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 10.6+ MB

# %%
df_benign['url']
# Out:
# 0                      https://www.google.com
# 1                     https://www.youtube.com
# 2                    https://www.facebook.com
# 3                       https://www.baidu.com
# 4                   https://www.wikipedia.org
#                          ...
# 345732    https://koreantaekwondo.tripod.com/
# 345733       https://taekwondo.wisebytes.net/
# 345734           https://www.steveconway.net/
# 345735                   https://www.tkd.net/
# 345736        https://www.taekwondobible.com/
# Name: url, Length: 345737, dtype: object

# %%
df_benign.duplicated().sum()
# Out:
# 0

# %%
df_phishing.head()
# Out:
#    Unnamed: 0                                                url      Type  \
# 0           0  https://docs.google.com/presentation/d/e/2PACX...  phishing
# 1           1    https://btttelecommunniccatiion.weeblysite.com/  phishing
# 2           2                        https://kq0hgp.webwave.dev/  phishing
# 3           3  https://brittishtele1bt-69836.getresponsesite....  phishing
# 4           4         https://bt-internet-105056.weeblysite.com/  phishing
#
#    label
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df_phishing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159245 entries, 0 to 159244
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  159245 non-null  int64
#  1   url         159245 non-null  object
#  2   Type        159245 non-null  object
#  3   label       159245 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 4.9+ MB

# %%
df_phishing.isna().sum()
# Out:
# Unnamed: 0    0
# url           0
# Type          0
# label         0
# dtype: int64

# %%
df_phishing.columns
# Out:
# Index(['Unnamed: 0', 'url', 'Type', 'label'], dtype='object')

# %%
df_phishing.shape
# Out:
# (159245, 4)

# %%
df_phishing.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # concat both dataframes

# %%
df = pd.concat([df_phishing, df_benign], ignore_index=True)

# %%
df['label'].value_counts()
# Out:
# label
# 0    345737
# 1    159245
# Name: count, dtype: int64

# %%
df.to_csv('combined_data.csv')
